# %% [markdown]
# # Show segmentation masks and track objects in a video.

# %%
# Show segmentation masks and track objects in a video.
import cv2
import os
import csv
import numpy as np
from ultralytics import YOLO
from ultralytics.utils.plotting import Annotator, colors

# === Video and Model Setup ===
video_path = "data/road-pothole-1.MP4"
model = YOLO("runs/train19/weights/best.pt")  # segmentation model
cap = cv2.VideoCapture(video_path)

# === Video Properties ===
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH,
                                       cv2.CAP_PROP_FRAME_HEIGHT,
                                       cv2.CAP_PROP_FPS))

# === Output Video Path ===
base, ext = os.path.splitext(video_path)
new_video_path = f"{base}_seg-tracking_train3{ext}"
out = cv2.VideoWriter(new_video_path, cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

# === Display Window Setup ===
cv2.namedWindow("instance-segmentation-object-tracking", cv2.WINDOW_NORMAL)
cv2.resizeWindow("instance-segmentation-object-tracking", 1280, 720)

# === CSV Logging Setup ===
csv_path = f"{base}_tracking_results.csv"
csv_file = open(csv_path, mode='w', newline='')
csv_writer = csv.writer(csv_file)
csv_writer.writerow(["Frame", "Track_ID"])

# === Tracking Variables ===
pot_holes_id = set()
frame_idx = 0

# === Frame Processing Loop ===
while True:
    ret, im0 = cap.read()
    if not ret:
        print("Video frame is empty or video processing has been successfully completed.")
        break

    annotator = Annotator(im0, line_width=5)
    results = model.track(im0, persist=True)

    if results[0].boxes.id is not None and results[0].masks is not None:
        masks = results[0].masks.xy
        track_ids = results[0].boxes.id.int().cpu().tolist()

        for mask, track_id in zip(masks, track_ids):
            color = colors(int(track_id), True)
            txt_color = annotator.get_txt_color(color)


            # Convert polygon mask to NumPy format and draw it
            mask_np = np.array([mask], dtype=np.int32)
            cv2.fillPoly(im0, mask_np, color)

            # Optional: add label near first point of mask
            x, y = mask[0]
            cv2.putText(im0, str(track_id), (int(x), int(y)), cv2.FONT_HERSHEY_SIMPLEX,
                        0.7, txt_color, 2, cv2.LINE_AA)

            # Track new unique potholes
            if track_id not in pot_holes_id:
                pot_holes_id.add(track_id)

            # Write to CSV
            csv_writer.writerow([frame_idx, track_id])

    # Overlay tracked count on video
    cv2.putText(im0, f"Potholes tracked: {len(pot_holes_id)}", (50, 50),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2, cv2.LINE_AA)

    # Write frame to video and show window
    out.write(im0)
    cv2.imshow("instance-segmentation-object-tracking", im0)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

    frame_idx += 1

# === Cleanup ===
out.release()
cap.release()
csv_file.close()
cv2.destroyAllWindows()

# === Summary Output ===
print("Potholes ID: ", list(pot_holes_id))
print("Number of potholes detected: ", len(pot_holes_id))
print(f"Tracking results saved to: {csv_path}")
# Out:
# 0: 384x640 (no detections), 69.0ms
# Speed: 3.3ms preprocess, 69.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Potholes ID:  []
# Number of potholes detected:  0
# Tracking results saved to: data/road-pothole-1_tracking_results.csv

# %% [markdown]
# # Show bounding box and track ID when detecting a pothole

# %%
import cv2
import os
import csv
from ultralytics import YOLO
from ultralytics.utils.plotting import Annotator, colors

# === Video and Model Setup ===
video_path = "data/videos/GX011215_0-7_24fps.MP4"
model = YOLO("runs/train3/weights/best.pt")  # Segmentation or detection model
cap = cv2.VideoCapture(video_path)

# === Video Properties ===
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH,
                                       cv2.CAP_PROP_FRAME_HEIGHT,
                                       cv2.CAP_PROP_FPS))

# === Output Video Path ===
base, ext = os.path.splitext(video_path)
new_video_path = f"{base}_bbox-tracking_train3{ext}"
out = cv2.VideoWriter(new_video_path, cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

# === Display Window Setup ===
cv2.namedWindow("bbox-tracking", cv2.WINDOW_NORMAL)
cv2.resizeWindow("bbox-tracking", 1280, 720)

# === CSV Logging Setup ===
csv_path = f"{base}_bbox_tracking_results.csv"
csv_file = open(csv_path, mode='w', newline='')
csv_writer = csv.writer(csv_file)
csv_writer.writerow(["Frame", "Track_ID", "X1", "Y1", "X2", "Y2"])

# === Tracking Variables ===
pot_holes_id = set()
frame_idx = 0
last_frame_per_id = {}  # track_id: (frame image, frame number, bbox)
video_base_name = os.path.splitext(os.path.basename(video_path))[0]

# === Frame Processing Loop ===
while True:
    ret, im0 = cap.read()
    if not ret:
        print("Video frame is empty or video processing has been successfully completed.")
        break

    annotator = Annotator(im0, line_width=3)
    results = model.track(im0, persist=True)

    if results[0].boxes.id is not None:
        boxes = results[0].boxes.xyxy.cpu().numpy()   # [x1, y1, x2, y2]
        track_ids = results[0].boxes.id.int().cpu().tolist()

        for box, track_id in zip(boxes, track_ids):
            x1, y1, x2, y2 = map(int, box)
            color = colors(int(track_id), True)
            label = str(track_id)

            annotator.box_label([x1, y1, x2, y2], label, color=color)
            pot_holes_id.add(track_id)
            csv_writer.writerow([frame_idx, track_id, x1, y1, x2, y2])
            last_frame_per_id[track_id] = (im0.copy(), frame_idx)

    cv2.putText(im0, f"Potholes tracked: {len(pot_holes_id)}", (30, 40),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2, cv2.LINE_AA)

    out.write(im0)
    cv2.imshow("bbox-tracking", im0)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

    frame_idx += 1

# === Cleanup ===
out.release()
cap.release()
csv_file.close()
cv2.destroyAllWindows()

# === Save full last frame for each track ID ===
output_dir = f"{base}_pothole_frames"
os.makedirs(output_dir, exist_ok=True)

for track_id, (frame_img, frame_num) in last_frame_per_id.items():
    output_filename = f"{video_base_name}_Frame{frame_num}_ID{track_id}.jpg"
    output_path = os.path.join(output_dir, output_filename)
    cv2.imwrite(output_path, frame_img)

print("Potholes ID: ", list(pot_holes_id))
print("Number of potholes detected: ", len(pot_holes_id))
print(f"Tracking results saved to: {csv_path}")
print(f"Saved {len(last_frame_per_id)} full-frame images to: {output_dir}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 28
#      26 # === CSV Logging Setup ===
#      27 csv_path = f"{base}_bbox_tracking_results.csv"
# ---> 28 csv_file = open(csv_path, mode='w', newline='')
#      29 csv_writer = csv.writer(csv_file)
#      30 csv_writer.writerow(["Frame", "Track_ID", "X1", "Y1", "X2", "Y2"])
#
# File ~/miniconda3/envs/581_yolo/lib/python3.12/site-packages/IPython/core/interactiveshell.py:326, in _modified_open(file, *args, **kwargs)
#     319 if file in {0, 1, 2}:
#     320     raise ValueError(
#     321         f"IPython won't let you open fd={file} by default "
#     322         "as it is likely to crash IPython. If you know what you are doing, "
#     323         "you can use builtins' open."
#     324     )
# --> 326 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/videos/GX011215_0-7_24fps_bbox_tracking_results.csv'

# %% [markdown]
# # Bounding box with segmentation labels
# EDGE_MARGIN = 50  # Pixels away from frame edges to consider as pothole full image.
# Estimates GPS coordinates for each saved pothole image using frame timing and embeds them using exiftool.

# %%
import cv2
import os
import csv
from datetime import datetime, timedelta
from ultralytics import YOLO
from ultralytics.utils.plotting import Annotator, colors

# === Video and Model Setup ===
video_path = "data/road-pothole-1.MP4"
model = YOLO("runs/train19/weights/best.pt")  # Segmentation or detection model
cap = cv2.VideoCapture(video_path)

# === Video GPS information ===
def get_gps_coords(video_path):
    cmd = f'exiftool -p kml.fmt -ee3 {video_path} > {video_path}.kml'
    os.system(cmd)
    coords = []
    with open(f'{video_path}.kml', 'r') as f:
        lines = f.readlines()
    for line in lines:
        if 'coordinates' in line:
            line = line.replace('<coordinates>', '').replace(',0</coordinates>', '')
            coords.append([float(x) for x in line.split(',')])
    return coords

coords = get_gps_coords(video_path)

# === Video Properties ===
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH,
                                       cv2.CAP_PROP_FRAME_HEIGHT,
                                       cv2.CAP_PROP_FPS))

# Try to get creation time using exiftool
creation_time_str = os.popen(f"exiftool -CreateDate -d '%Y-%m-%d %H:%M:%S' {video_path}").read()
creation_time = None
if "Create Date" in creation_time_str:
    try:
        creation_time = datetime.strptime(creation_time_str.split(': ', 1)[-1].strip(), '%Y-%m-%d %H:%M:%S')
    except:
        creation_time = None

# === Output Video Path ===
base, ext = os.path.splitext(video_path)
new_video_path = f"{base}_pothole-tracking{ext}"
out = cv2.VideoWriter(new_video_path, cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

# === Display Window Setup ===
cv2.namedWindow("pothole-tracking", cv2.WINDOW_NORMAL)
cv2.resizeWindow("pothole-tracking", 1280, 720)

# === Tracking Variables ===
pot_holes_id = set()
frame_idx = 0
last_frame_per_id = {}  # track_id: (frame number, frame image, mask, box)
video_base_name = os.path.splitext(os.path.basename(video_path))[0]

EDGE_MARGIN = 50  # Pixels away from frame edges to consider as safe

# === Frame Processing Loop ===
while True:
    ret, im0 = cap.read()
    if not ret:
        print("Video frame is empty or video processing has been successfully completed.")
        break

    annotator = Annotator(im0, line_width=3)
    results = model.track(im0, persist=True)

    if results[0].boxes.id is not None:
        boxes = results[0].boxes.xyxy.cpu().numpy()
        track_ids = results[0].boxes.id.int().cpu().tolist()
        masks = results[0].masks.xy if results[0].masks is not None else [None] * len(track_ids)

        for box, track_id, mask in zip(boxes, track_ids, masks):
            x1, y1, x2, y2 = map(int, box)

            if (x1 <= EDGE_MARGIN or y1 <= EDGE_MARGIN or
                x2 >= w - EDGE_MARGIN or y2 >= h - EDGE_MARGIN):
                continue

            color = colors(int(track_id), True)
            label = str(track_id)

            annotator.box_label([x1, y1, x2, y2], label, color=color)
            pot_holes_id.add(track_id)
            last_frame_per_id[track_id] = (frame_idx, im0.copy(), mask, (x1, y1, x2, y2))

    overlay = im0.copy()
    alpha = 0.6
    text1 = f"Total potholes found: {len(pot_holes_id)}"
    text2 = f"Pothole tracked: {pot_holes_id}"

    (tw1, th1), _ = cv2.getTextSize(text1, cv2.FONT_HERSHEY_SIMPLEX, 2, 3)
    (tw2, th2), _ = cv2.getTextSize(text2, cv2.FONT_HERSHEY_SIMPLEX, 2, 3)

    cv2.rectangle(overlay, (25, 65 - th1), (35 + tw1, 105), (255, 255, 255), -1)
    cv2.rectangle(overlay, (25, 5 - th2), (35 + tw2, 45), (255, 255, 255), -1)

    cv2.addWeighted(overlay, alpha, im0, 1 - alpha, 0, im0)

    cv2.putText(im0, text1, (30, 100), cv2.FONT_HERSHEY_SIMPLEX, 2, (128, 0, 128), 3, cv2.LINE_AA)
    cv2.putText(im0, text2, (30, 40), cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 0, 0), 3, cv2.LINE_AA)

    out.write(im0)
    cv2.imshow("bbox-tracking", im0)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

    frame_idx += 1

# === Cleanup ===
out.release()
cap.release()
cv2.destroyAllWindows()

# === Save last frame and YOLO v11 segmentation labels for each Track ID ===
output_dir = f"{base}_pothole_frames"
os.makedirs(output_dir, exist_ok=True)

# Update CSV to only log final detections with GPS and timestamp
csv_path = f"{base}_pothole_tracking_results.csv"
with open(csv_path, mode='w', newline='') as csv_file:
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(["Frame", "Track_ID", "X1", "Y1", "X2", "Y2", "Latitude", "Longitude", "Timestamp"])

    for track_id, (frame_num, frame_img, mask, (x1, y1, x2, y2)) in last_frame_per_id.items():
        output_filename = f"{video_base_name}_Frame{frame_num}_ID{track_id}.jpg"
        output_path = os.path.join(output_dir, output_filename)
        cv2.imwrite(output_path, frame_img)

        cur_gps = [None, None]
        if coords and frame_num // int(fps) < len(coords) - 1:
            i = frame_num
            fps_int = int(fps)
            idx = i // fps_int
            frac = (i % fps_int) / fps_int
            GPS_1 = coords[idx]
            GPS_2 = coords[idx + 1]
            cur_gps = [
                GPS_1[0] + (GPS_2[0] - GPS_1[0]) * frac,
                GPS_1[1] + (GPS_2[1] - GPS_1[1]) * frac
            ]

            latitude_ref = 'N' if cur_gps[1] >= 0 else 'S'
            longitude_ref = 'E' if cur_gps[0] >= 0 else 'W'
            cmd = f"exiftool -GPSLatitude={abs(cur_gps[1])} -GPSLongitude={abs(cur_gps[0])} -GPSLatitudeRef={latitude_ref} -GPSLongitudeRef={longitude_ref} {output_path}"
            os.system(cmd)

        timestamp = ""
        if creation_time:
            timestamp_dt = creation_time + timedelta(seconds=(frame_num / fps))
            timestamp = timestamp_dt.strftime('%m-%d-%Y %H:%M:%S')

        csv_writer.writerow([frame_num, track_id, x1, y1, x2, y2, cur_gps[1], cur_gps[0], timestamp])

        if mask is not None:
            class_id = 0  # pothole class
            normalized_coords = [f"{x / w:.6f} {y / h:.6f}" for x, y in mask]
            label_line = f"{class_id} " + " ".join(normalized_coords)
            label_filename = f"{video_base_name}_Frame{frame_num}_ID{track_id}.txt"
            label_path = os.path.join(output_dir, label_filename)
            with open(label_path, 'w') as label_file:
                label_file.write(label_line + "\n")

# === Delete *.jpg_original files ===
for file in os.listdir(output_dir):
    if file.endswith(".jpg_original"):
        os.remove(os.path.join(output_dir, file))

print("Potholes ID: ", list(pot_holes_id))
print("Number of potholes detected: ", len(pot_holes_id))
print(f"Tracking results saved to: {csv_path}")
print(f"Saved {len(last_frame_per_id)} full-frame images and label files to: {output_dir}")
# Out:
# Warning: [Minor] Tag 'Doc1:filename' not defined - data/road-pothole-1.MP4
# 0: 384x640 (no detections), 48.4ms
# Speed: 1.8ms preprocess, 48.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.3ms
# Speed: 2.5ms preprocess, 33.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 38.3ms
# Speed: 2.7ms preprocess, 38.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.6ms
# Speed: 1.9ms preprocess, 19.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.1ms
# Speed: 2.1ms preprocess, 27.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.4ms
# Speed: 2.9ms preprocess, 44.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.4ms
# Speed: 2.1ms preprocess, 26.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 16.0ms
# Speed: 2.8ms preprocess, 16.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 26.2ms
# Speed: 4.4ms preprocess, 26.2ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 29.8ms
# Speed: 2.7ms preprocess, 29.8ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 17.2ms
# Speed: 9.0ms preprocess, 17.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 15.7ms
# Speed: 3.3ms preprocess, 15.7ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.7ms
# Speed: 3.9ms preprocess, 16.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 15.9ms
# Speed: 2.3ms preprocess, 15.9ms inference, 19.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 15.9ms
# Speed: 1.9ms preprocess, 15.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 30.4ms
# Speed: 3.0ms preprocess, 30.4ms inference, 17.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.7ms
# Speed: 3.7ms preprocess, 34.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.6ms
# Speed: 10.5ms preprocess, 39.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.4ms
# Speed: 2.2ms preprocess, 20.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.3ms
# Speed: 2.4ms preprocess, 12.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.0ms
# Speed: 3.3ms preprocess, 7.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 8.7ms
# Speed: 1.7ms preprocess, 8.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.2ms
# Speed: 2.4ms preprocess, 13.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.8ms
# Speed: 3.4ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.6ms
# Speed: 3.7ms preprocess, 12.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.5ms
# Speed: 5.1ms preprocess, 9.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.4ms
# Speed: 2.5ms preprocess, 12.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.2ms
# Speed: 1.8ms preprocess, 9.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 14.0ms
# Speed: 2.6ms preprocess, 14.0ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.9ms
# Speed: 3.4ms preprocess, 11.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 8.4ms
# Speed: 2.1ms preprocess, 8.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.6ms
# Speed: 1.9ms preprocess, 18.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.6ms
# Speed: 5.5ms preprocess, 14.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.9ms
# Speed: 2.0ms preprocess, 20.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.7ms
# Speed: 2.2ms preprocess, 10.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.7ms
# Speed: 1.7ms preprocess, 14.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.7ms
# Speed: 2.3ms preprocess, 16.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.0ms
# Speed: 2.2ms preprocess, 16.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.7ms
# Speed: 1.8ms preprocess, 14.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.2ms
# Speed: 2.6ms preprocess, 14.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.9ms
# Speed: 3.5ms preprocess, 14.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.5ms
# Speed: 1.9ms preprocess, 14.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.7ms
# Speed: 2.0ms preprocess, 15.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.8ms
# Speed: 2.5ms preprocess, 12.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.1ms
# Speed: 1.9ms preprocess, 12.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.8ms
# Speed: 2.1ms preprocess, 13.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.3ms
# Speed: 4.2ms preprocess, 27.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.3ms
# Speed: 2.0ms preprocess, 15.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.4ms
# Speed: 2.0ms preprocess, 14.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.2ms
# Speed: 3.1ms preprocess, 41.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.9ms
# Speed: 4.2ms preprocess, 16.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.8ms
# Speed: 3.8ms preprocess, 15.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.6ms
# Speed: 2.8ms preprocess, 19.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 36.4ms
# Speed: 4.8ms preprocess, 36.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.7ms
# Speed: 4.2ms preprocess, 15.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.7ms
# Speed: 3.5ms preprocess, 13.7ms inference, 10.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.6ms
# Speed: 3.4ms preprocess, 15.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 38.3ms
# Speed: 4.5ms preprocess, 38.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 29.7ms
# Speed: 4.4ms preprocess, 29.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.7ms
# Speed: 3.8ms preprocess, 26.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.5ms
# Speed: 3.5ms preprocess, 24.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 36.5ms
# Speed: 5.8ms preprocess, 36.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.3ms
# Speed: 4.3ms preprocess, 31.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.4ms
# Speed: 2.6ms preprocess, 14.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.4ms
# Speed: 2.8ms preprocess, 33.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.8ms
# Speed: 2.2ms preprocess, 16.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.7ms
# Speed: 4.5ms preprocess, 14.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 30.6ms
# Speed: 2.8ms preprocess, 30.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.1ms
# Speed: 2.3ms preprocess, 13.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 37.0ms
# Speed: 2.6ms preprocess, 37.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.1ms
# Speed: 3.7ms preprocess, 15.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.8ms
# Speed: 2.2ms preprocess, 16.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.0ms
# Speed: 4.1ms preprocess, 32.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 38.7ms
# Speed: 3.4ms preprocess, 38.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.7ms
# Speed: 3.3ms preprocess, 15.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 36.3ms
# Speed: 3.1ms preprocess, 36.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 30.0ms
# Speed: 3.6ms preprocess, 30.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 37.3ms
# Speed: 2.8ms preprocess, 37.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.4ms
# Speed: 3.1ms preprocess, 25.4ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.9ms
# Speed: 5.0ms preprocess, 15.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.1ms
# Speed: 2.0ms preprocess, 14.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.7ms
# Speed: 3.0ms preprocess, 35.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.9ms
# Speed: 3.4ms preprocess, 23.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.8ms
# Speed: 3.6ms preprocess, 15.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.5ms
# Speed: 2.5ms preprocess, 16.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.1ms
# Speed: 3.0ms preprocess, 17.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.9ms
# Speed: 2.5ms preprocess, 16.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.6ms
# Speed: 3.3ms preprocess, 35.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.7ms
# Speed: 5.2ms preprocess, 17.7ms inference, 9.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 37.1ms
# Speed: 2.4ms preprocess, 37.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.9ms
# Speed: 2.8ms preprocess, 34.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.2ms
# Speed: 3.6ms preprocess, 35.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.8ms
# Speed: 3.0ms preprocess, 23.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.8ms
# Speed: 2.5ms preprocess, 27.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.2ms
# Speed: 2.6ms preprocess, 34.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 37.9ms
# Speed: 2.3ms preprocess, 37.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.4ms
# Speed: 3.2ms preprocess, 15.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.5ms
# Speed: 3.4ms preprocess, 15.5ms inference, 18.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.1ms
# Speed: 3.0ms preprocess, 26.1ms inference, 11.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.6ms
# Speed: 3.3ms preprocess, 35.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.8ms
# Speed: 3.5ms preprocess, 42.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.2ms
# Speed: 2.9ms preprocess, 16.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.0ms
# Speed: 2.3ms preprocess, 16.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.8ms
# Speed: 2.2ms preprocess, 15.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.2ms
# Speed: 2.1ms preprocess, 18.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.1ms
# Speed: 3.3ms preprocess, 16.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.0ms
# Speed: 3.7ms preprocess, 40.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.5ms
# Speed: 3.9ms preprocess, 34.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 28.8ms
# Speed: 3.2ms preprocess, 28.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.6ms
# Speed: 3.8ms preprocess, 17.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.8ms
# Speed: 2.1ms preprocess, 12.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.4ms
# Speed: 2.9ms preprocess, 34.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 36.8ms
# Speed: 4.4ms preprocess, 36.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.3ms
# Speed: 2.7ms preprocess, 15.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.5ms
# Speed: 2.6ms preprocess, 17.5ms inference, 9.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.3ms
# Speed: 1.9ms preprocess, 14.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.7ms
# Speed: 3.5ms preprocess, 40.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.9ms
# Speed: 2.8ms preprocess, 35.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.0ms
# Speed: 2.5ms preprocess, 39.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.4ms
# Speed: 2.4ms preprocess, 33.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.1ms
# Speed: 2.3ms preprocess, 35.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.8ms
# Speed: 3.9ms preprocess, 25.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.8ms
# Speed: 3.6ms preprocess, 15.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.0ms
# Speed: 2.1ms preprocess, 34.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.5ms
# Speed: 3.9ms preprocess, 34.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 38.4ms
# Speed: 4.2ms preprocess, 38.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.7ms
# Speed: 3.7ms preprocess, 33.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.0ms
# Speed: 4.3ms preprocess, 42.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 37.3ms
# Speed: 2.3ms preprocess, 37.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.3ms
# Speed: 2.9ms preprocess, 16.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.2ms
# Speed: 2.5ms preprocess, 35.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.1ms
# Speed: 2.3ms preprocess, 18.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.5ms
# Speed: 2.8ms preprocess, 39.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.7ms
# Speed: 4.5ms preprocess, 39.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.2ms
# Speed: 3.1ms preprocess, 41.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.6ms
# Speed: 2.3ms preprocess, 17.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.6ms
# Speed: 1.9ms preprocess, 16.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 38.3ms
# Speed: 3.4ms preprocess, 38.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 38.5ms
# Speed: 2.9ms preprocess, 38.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.9ms
# Speed: 2.7ms preprocess, 43.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.6ms
# Speed: 3.6ms preprocess, 25.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.4ms
# Speed: 3.6ms preprocess, 27.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 28.3ms
# Speed: 3.9ms preprocess, 28.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.5ms
# Speed: 2.1ms preprocess, 15.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 29.6ms
# Speed: 4.1ms preprocess, 29.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 29.2ms
# Speed: 1.9ms preprocess, 29.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.6ms
# Speed: 1.8ms preprocess, 27.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.8ms
# Speed: 2.1ms preprocess, 16.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.7ms
# Speed: 4.5ms preprocess, 33.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 38.8ms
# Speed: 2.4ms preprocess, 38.8ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 58.0ms
# Speed: 3.6ms preprocess, 58.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 31.6ms
# Speed: 3.2ms preprocess, 31.6ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 12.6ms
# Speed: 2.2ms preprocess, 12.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.4ms
# Speed: 3.9ms preprocess, 15.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 32.4ms
# Speed: 3.9ms preprocess, 32.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 34.8ms
# Speed: 2.3ms preprocess, 34.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 35.1ms
# Speed: 2.6ms preprocess, 35.1ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 12.7ms
# Speed: 1.8ms preprocess, 12.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 27.5ms
# Speed: 1.8ms preprocess, 27.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 24.3ms
# Speed: 2.7ms preprocess, 24.3ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 16.4ms
# Speed: 2.3ms preprocess, 16.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 27.5ms
# Speed: 2.1ms preprocess, 27.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 25.8ms
# Speed: 2.3ms preprocess, 25.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 31.1ms
# Speed: 3.5ms preprocess, 31.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 57.1ms
# Speed: 2.3ms preprocess, 57.1ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 56.5ms
# Speed: 3.0ms preprocess, 56.5ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 42.2ms
# Speed: 2.3ms preprocess, 42.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 26.7ms
# Speed: 2.2ms preprocess, 26.7ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 26.9ms
# Speed: 1.8ms preprocess, 26.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 24.7ms
# Speed: 3.0ms preprocess, 24.7ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 17.1ms
# Speed: 1.7ms preprocess, 17.1ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 16.3ms
# Speed: 2.2ms preprocess, 16.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 14.1ms
# Speed: 1.7ms preprocess, 14.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 15.4ms
# Speed: 2.3ms preprocess, 15.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 26.6ms
# Speed: 2.2ms preprocess, 26.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 17.5ms
# Speed: 2.1ms preprocess, 17.5ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 24.7ms
# Speed: 1.8ms preprocess, 24.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 26.7ms
# Speed: 2.6ms preprocess, 26.7ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 17.5ms
# Speed: 2.2ms preprocess, 17.5ms inference, 11.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 52.4ms
# Speed: 2.3ms preprocess, 52.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 49.5ms
# Speed: 2.0ms preprocess, 49.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 49.2ms
# Speed: 3.7ms preprocess, 49.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 51.9ms
# Speed: 2.0ms preprocess, 51.9ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 24.7ms
# Speed: 2.2ms preprocess, 24.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 26.2ms
# Speed: 2.6ms preprocess, 26.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 26.1ms
# Speed: 2.0ms preprocess, 26.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 32.5ms
# Speed: 2.9ms preprocess, 32.5ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 26.5ms
# Speed: 3.3ms preprocess, 26.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 18.3ms
# Speed: 1.9ms preprocess, 18.3ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 30.2ms
# Speed: 2.8ms preprocess, 30.2ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 16.9ms
# Speed: 1.9ms preprocess, 16.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 16.9ms
# Speed: 1.7ms preprocess, 16.9ms inference, 12.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 27.8ms
# Speed: 1.9ms preprocess, 27.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 16.1ms
# Speed: 1.8ms preprocess, 16.1ms inference, 11.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 16.4ms
# Speed: 2.6ms preprocess, 16.4ms inference, 10.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 48.6ms
# Speed: 4.0ms preprocess, 48.6ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 51.1ms
# Speed: 2.9ms preprocess, 51.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 48.3ms
# Speed: 3.2ms preprocess, 48.3ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 52.3ms
# Speed: 2.3ms preprocess, 52.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 52.6ms
# Speed: 2.4ms preprocess, 52.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 56.2ms
# Speed: 2.9ms preprocess, 56.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 48.8ms
# Speed: 2.8ms preprocess, 48.8ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 17.5ms
# Speed: 1.9ms preprocess, 17.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 33.2ms
# Speed: 2.3ms preprocess, 33.2ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 31.2ms
# Speed: 2.0ms preprocess, 31.2ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 27.2ms
# Speed: 2.5ms preprocess, 27.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 27.2ms
# Speed: 2.4ms preprocess, 27.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 18.8ms
# Speed: 2.9ms preprocess, 18.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 27.5ms
# Speed: 2.3ms preprocess, 27.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 28.0ms
# Speed: 2.7ms preprocess, 28.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 27.9ms
# Speed: 2.6ms preprocess, 27.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 27.6ms
# Speed: 1.9ms preprocess, 27.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 28.5ms
# Speed: 2.0ms preprocess, 28.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 28.2ms
# Speed: 2.2ms preprocess, 28.2ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 52.0ms
# Speed: 3.0ms preprocess, 52.0ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 50.4ms
# Speed: 2.5ms preprocess, 50.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 61.4ms
# Speed: 2.6ms preprocess, 61.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 52.7ms
# Speed: 2.6ms preprocess, 52.7ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 50.0ms
# Speed: 2.4ms preprocess, 50.0ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 potholes, 62.3ms
# Speed: 2.8ms preprocess, 62.3ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 potholes, 49.1ms
# Speed: 3.0ms preprocess, 49.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 potholes, 49.2ms
# Speed: 3.1ms preprocess, 49.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 16.1ms
# Speed: 3.7ms preprocess, 16.1ms inference, 12.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 28.2ms
# Speed: 3.2ms preprocess, 28.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 25.2ms
# Speed: 2.3ms preprocess, 25.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 17.6ms
# Speed: 2.1ms preprocess, 17.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 27.1ms
# Speed: 2.0ms preprocess, 27.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 29.2ms
# Speed: 3.0ms preprocess, 29.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 27.3ms
# Speed: 3.6ms preprocess, 27.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 28.8ms
# Speed: 2.3ms preprocess, 28.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 26.7ms
# Speed: 2.2ms preprocess, 26.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 26.8ms
# Speed: 2.7ms preprocess, 26.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 27.9ms
# Speed: 1.7ms preprocess, 27.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 28.1ms
# Speed: 3.8ms preprocess, 28.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 47.1ms
# Speed: 2.4ms preprocess, 47.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 51.7ms
# Speed: 3.1ms preprocess, 51.7ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 46.4ms
# Speed: 3.9ms preprocess, 46.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 47.3ms
# Speed: 3.7ms preprocess, 47.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 48.1ms
# Speed: 2.4ms preprocess, 48.1ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 54.6ms
# Speed: 4.4ms preprocess, 54.6ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 68.0ms
# Speed: 4.0ms preprocess, 68.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 51.3ms
# Speed: 2.5ms preprocess, 51.3ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 29.1ms
# Speed: 2.7ms preprocess, 29.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 26.3ms
# Speed: 3.5ms preprocess, 26.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 31.0ms
# Speed: 2.7ms preprocess, 31.0ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 24.6ms
# Speed: 2.1ms preprocess, 24.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 31.9ms
# Speed: 2.8ms preprocess, 31.9ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 31.7ms
# Speed: 2.8ms preprocess, 31.7ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 16.6ms
# Speed: 2.4ms preprocess, 16.6ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 31.9ms
# Speed: 3.8ms preprocess, 31.9ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 30.3ms
# Speed: 2.6ms preprocess, 30.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 27.9ms
# Speed: 4.0ms preprocess, 27.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potholes, 17.0ms
# Speed: 4.7ms preprocess, 17.0ms inference, 12.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 50.0ms
# Speed: 3.1ms preprocess, 50.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 53.1ms
# Speed: 2.6ms preprocess, 53.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 50.8ms
# Speed: 2.0ms preprocess, 50.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 53.2ms
# Speed: 3.3ms preprocess, 53.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.1ms
# Speed: 2.4ms preprocess, 55.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.4ms
# Speed: 2.6ms preprocess, 55.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.1ms
# Speed: 2.1ms preprocess, 15.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.4ms
# Speed: 2.4ms preprocess, 26.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.0ms
# Speed: 2.7ms preprocess, 18.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.8ms
# Speed: 3.0ms preprocess, 14.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.2ms
# Speed: 3.2ms preprocess, 26.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 29.2ms
# Speed: 2.4ms preprocess, 29.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.5ms
# Speed: 2.6ms preprocess, 17.5ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.5ms
# Speed: 1.8ms preprocess, 27.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.4ms
# Speed: 1.9ms preprocess, 27.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.0ms
# Speed: 2.9ms preprocess, 26.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.5ms
# Speed: 2.3ms preprocess, 26.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 28.1ms
# Speed: 1.7ms preprocess, 28.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 17.0ms
# Speed: 3.3ms preprocess, 17.0ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 24.5ms
# Speed: 3.7ms preprocess, 24.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 28.7ms
# Speed: 2.2ms preprocess, 28.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 47.4ms
# Speed: 3.8ms preprocess, 47.4ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 48.9ms
# Speed: 3.1ms preprocess, 48.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 50.2ms
# Speed: 3.7ms preprocess, 50.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 52.5ms
# Speed: 2.8ms preprocess, 52.5ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 62.5ms
# Speed: 3.1ms preprocess, 62.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 30.2ms
# Speed: 2.0ms preprocess, 30.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 27.6ms
# Speed: 4.0ms preprocess, 27.6ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 26.1ms
# Speed: 1.8ms preprocess, 26.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 27.8ms
# Speed: 2.4ms preprocess, 27.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 26.8ms
# Speed: 2.4ms preprocess, 26.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 27.5ms
# Speed: 2.0ms preprocess, 27.5ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 24.1ms
# Speed: 1.9ms preprocess, 24.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 26.1ms
# Speed: 2.3ms preprocess, 26.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 28.7ms
# Speed: 3.2ms preprocess, 28.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 26.8ms
# Speed: 2.1ms preprocess, 26.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 31.9ms
# Speed: 3.5ms preprocess, 31.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 60.5ms
# Speed: 3.5ms preprocess, 60.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 45.9ms
# Speed: 2.5ms preprocess, 45.9ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 48.7ms
# Speed: 2.5ms preprocess, 48.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 64.6ms
# Speed: 2.4ms preprocess, 64.6ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 46.8ms
# Speed: 3.8ms preprocess, 46.8ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 47.0ms
# Speed: 4.5ms preprocess, 47.0ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 49.9ms
# Speed: 3.8ms preprocess, 49.9ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 49.7ms
# Speed: 2.1ms preprocess, 49.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 116.2ms
# Speed: 4.6ms preprocess, 116.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 11.3ms
# Speed: 1.8ms preprocess, 11.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 22.8ms
# Speed: 2.1ms preprocess, 22.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 13.9ms
# Speed: 2.2ms preprocess, 13.9ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 15.0ms
# Speed: 1.7ms preprocess, 15.0ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 16.3ms
# Speed: 2.3ms preprocess, 16.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 13.8ms
# Speed: 2.5ms preprocess, 13.8ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 14.9ms
# Speed: 1.7ms preprocess, 14.9ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 11.4ms
# Speed: 1.9ms preprocess, 11.4ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 16.7ms
# Speed: 1.8ms preprocess, 16.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 17.4ms
# Speed: 1.9ms preprocess, 17.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 15.9ms
# Speed: 1.7ms preprocess, 15.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 14.7ms
# Speed: 1.9ms preprocess, 14.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 13.5ms
# Speed: 2.9ms preprocess, 13.5ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 16.9ms
# Speed: 2.0ms preprocess, 16.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 19.8ms
# Speed: 2.1ms preprocess, 19.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 18.3ms
# Speed: 2.9ms preprocess, 18.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 17.5ms
# Speed: 2.1ms preprocess, 17.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 18.3ms
# Speed: 1.8ms preprocess, 18.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 22.2ms
# Speed: 1.8ms preprocess, 22.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 18.0ms
# Speed: 1.8ms preprocess, 18.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 21.0ms
# Speed: 1.9ms preprocess, 21.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 20.4ms
# Speed: 2.1ms preprocess, 20.4ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 38.5ms
# Speed: 1.9ms preprocess, 38.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 38.6ms
# Speed: 2.0ms preprocess, 38.6ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 37.0ms
# Speed: 2.4ms preprocess, 37.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.4ms
# Speed: 2.1ms preprocess, 49.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.7ms
# Speed: 1.8ms preprocess, 17.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.3ms
# Speed: 1.8ms preprocess, 16.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.5ms
# Speed: 1.8ms preprocess, 19.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 13.5ms
# Speed: 2.3ms preprocess, 13.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.0ms
# Speed: 3.7ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 19.1ms
# Speed: 2.1ms preprocess, 19.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 20.0ms
# Speed: 1.9ms preprocess, 20.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 16.8ms
# Speed: 1.9ms preprocess, 16.8ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 19.6ms
# Speed: 3.8ms preprocess, 19.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 16.8ms
# Speed: 1.8ms preprocess, 16.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 17.3ms
# Speed: 1.8ms preprocess, 17.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 17.1ms
# Speed: 1.9ms preprocess, 17.1ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 17.1ms
# Speed: 1.9ms preprocess, 17.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 17.5ms
# Speed: 2.2ms preprocess, 17.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 17.3ms
# Speed: 1.8ms preprocess, 17.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 17.4ms
# Speed: 2.3ms preprocess, 17.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 46.5ms
# Speed: 2.0ms preprocess, 46.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 38.8ms
# Speed: 2.5ms preprocess, 38.8ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 45.8ms
# Speed: 2.0ms preprocess, 45.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 38.6ms
# Speed: 2.3ms preprocess, 38.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 50.6ms
# Speed: 1.9ms preprocess, 50.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 34.5ms
# Speed: 3.6ms preprocess, 34.5ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 35.9ms
# Speed: 2.2ms preprocess, 35.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 35.9ms
# Speed: 3.0ms preprocess, 35.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 21.7ms
# Speed: 2.5ms preprocess, 21.7ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 21.2ms
# Speed: 2.1ms preprocess, 21.2ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 22.1ms
# Speed: 1.9ms preprocess, 22.1ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 17.3ms
# Speed: 4.0ms preprocess, 17.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 17.9ms
# Speed: 1.9ms preprocess, 17.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 18.8ms
# Speed: 1.9ms preprocess, 18.8ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 20.6ms
# Speed: 2.0ms preprocess, 20.6ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.1ms
# Speed: 2.1ms preprocess, 16.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.7ms
# Speed: 1.8ms preprocess, 22.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.2ms
# Speed: 1.9ms preprocess, 18.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.1ms
# Speed: 1.8ms preprocess, 18.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.9ms
# ...
#
# 0: 384x640 1 pothole, 20.4ms
# Speed: 2.1ms preprocess, 20.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 17.5ms
# Speed: 2.1ms preprocess, 17.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 18.0ms
# Speed: 1.8ms preprocess, 18.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 17.7ms
# Speed: 1.9ms preprocess, 17.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 42.2ms
# Speed: 2.2ms preprocess, 42.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 50.1ms
# Speed: 2.3ms preprocess, 50.1ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 38.2ms
# Speed: 2.3ms preprocess, 38.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 40.0ms
# Speed: 1.9ms preprocess, 40.0ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 34.1ms
# Speed: 1.9ms preprocess, 34.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 43.3ms
# Speed: 4.2ms preprocess, 43.3ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 44.3ms
# Speed: 3.6ms preprocess, 44.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 17.4ms
# Speed: 1.7ms preprocess, 17.4ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 13.2ms
# Speed: 2.5ms preprocess, 13.2ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 13.8ms
# Speed: 4.0ms preprocess, 13.8ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 17.2ms
# Speed: 1.8ms preprocess, 17.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 12.7ms
# Speed: 1.9ms preprocess, 12.7ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 16.7ms
# Speed: 2.0ms preprocess, 16.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 16.8ms
# Speed: 1.9ms preprocess, 16.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 18.8ms
# Speed: 2.0ms preprocess, 18.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 17.3ms
# Speed: 1.8ms preprocess, 17.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 16.8ms
# Speed: 1.8ms preprocess, 16.8ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 16.9ms
# Speed: 1.8ms preprocess, 16.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 16.3ms
# Speed: 1.7ms preprocess, 16.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 16.7ms
# Speed: 1.9ms preprocess, 16.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 18.7ms
# Speed: 2.0ms preprocess, 18.7ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 38.0ms
# Speed: 1.9ms preprocess, 38.0ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 32.7ms
# Speed: 1.9ms preprocess, 32.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 38.5ms
# Speed: 2.1ms preprocess, 38.5ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 38.4ms
# Speed: 2.3ms preprocess, 38.4ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 20.4ms
# Speed: 1.8ms preprocess, 20.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 21.5ms
# Speed: 1.8ms preprocess, 21.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 18.2ms
# Speed: 2.0ms preprocess, 18.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 17.6ms
# Speed: 1.8ms preprocess, 17.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pothole, 18.8ms
# Speed: 1.8ms preprocess, 18.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.2ms
# Speed: 2.1ms preprocess, 21.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.5ms
# Speed: 2.0ms preprocess, 18.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.7ms
# Speed: 2.0ms preprocess, 17.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.4ms
# Speed: 2.0ms preprocess, 18.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.6ms
# Speed: 3.8ms preprocess, 18.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.8ms
# Speed: 2.2ms preprocess, 17.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.3ms
# Speed: 1.8ms preprocess, 18.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.8ms
# Speed: 2.0ms preprocess, 18.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.8ms
# Speed: 3.2ms preprocess, 16.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.1ms
# Speed: 1.8ms preprocess, 18.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.3ms
# Speed: 2.1ms preprocess, 17.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.9ms
# Speed: 1.7ms preprocess, 18.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.4ms
# Speed: 1.8ms preprocess, 21.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.6ms
# Speed: 2.1ms preprocess, 25.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.3ms
# Speed: 2.0ms preprocess, 41.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.5ms
# Speed: 4.5ms preprocess, 25.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.7ms
# Speed: 1.9ms preprocess, 19.7ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.9ms
# Speed: 1.8ms preprocess, 17.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.9ms
# Speed: 1.8ms preprocess, 18.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.6ms
# Speed: 2.2ms preprocess, 17.6ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.7ms
# Speed: 1.8ms preprocess, 18.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.3ms
# Speed: 2.5ms preprocess, 18.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.0ms
# Speed: 2.2ms preprocess, 18.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.1ms
# Speed: 2.1ms preprocess, 19.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.6ms
# Speed: 2.0ms preprocess, 18.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.0ms
# Speed: 2.0ms preprocess, 19.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.5ms
# Speed: 1.9ms preprocess, 19.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.9ms
# Speed: 1.9ms preprocess, 18.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.4ms
# Speed: 1.8ms preprocess, 22.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.6ms
# Speed: 3.2ms preprocess, 18.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.5ms
# Speed: 2.4ms preprocess, 18.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.4ms
# Speed: 1.8ms preprocess, 18.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.3ms
# Speed: 1.8ms preprocess, 20.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.2ms
# Speed: 2.2ms preprocess, 18.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.6ms
# Speed: 1.9ms preprocess, 22.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.5ms
# Speed: 2.2ms preprocess, 35.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 38.8ms
# Speed: 2.1ms preprocess, 38.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.7ms
# Speed: 4.0ms preprocess, 18.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.2ms
# Speed: 1.9ms preprocess, 23.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.8ms
# Speed: 2.6ms preprocess, 17.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.8ms
# Speed: 3.8ms preprocess, 17.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.3ms
# Speed: 1.9ms preprocess, 17.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.6ms
# Speed: 2.2ms preprocess, 16.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.3ms
# Speed: 1.8ms preprocess, 19.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.3ms
# Speed: 2.9ms preprocess, 16.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.9ms
# Speed: 3.3ms preprocess, 19.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.3ms
# Speed: 1.9ms preprocess, 18.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.3ms
# Speed: 1.8ms preprocess, 20.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.2ms
# Speed: 2.2ms preprocess, 17.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.6ms
# Speed: 3.8ms preprocess, 18.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.3ms
# Speed: 1.9ms preprocess, 19.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.9ms
# Speed: 2.1ms preprocess, 22.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.3ms
# Speed: 2.7ms preprocess, 18.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.0ms
# Speed: 4.6ms preprocess, 19.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.0ms
# Speed: 2.0ms preprocess, 19.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.1ms
# Speed: 4.4ms preprocess, 18.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.3ms
# Speed: 2.1ms preprocess, 22.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.6ms
# Speed: 1.9ms preprocess, 19.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 37.1ms
# Speed: 2.0ms preprocess, 37.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.4ms
# Speed: 2.0ms preprocess, 34.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.4ms
# Speed: 2.8ms preprocess, 19.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.7ms
# Speed: 2.3ms preprocess, 17.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.8ms
# Speed: 2.3ms preprocess, 17.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.1ms
# Speed: 3.4ms preprocess, 20.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.3ms
# Speed: 3.0ms preprocess, 19.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.9ms
# Speed: 1.8ms preprocess, 17.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.7ms
# Speed: 1.9ms preprocess, 19.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.7ms
# Speed: 1.8ms preprocess, 19.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.8ms
# Speed: 1.8ms preprocess, 21.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.9ms
# Speed: 2.2ms preprocess, 17.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.0ms
# Speed: 1.7ms preprocess, 18.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 potholes, 18.5ms
# Speed: 1.7ms preprocess, 18.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.4ms
# Speed: 4.2ms preprocess, 19.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.0ms
# Speed: 1.8ms preprocess, 18.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.2ms
# Speed: 1.7ms preprocess, 19.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.3ms
# Speed: 2.0ms preprocess, 20.3ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.6ms
# Speed: 3.6ms preprocess, 13.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.3ms
# Speed: 2.0ms preprocess, 20.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Video frame is empty or video processing has been successfully completed.
#     1 image files updated
#     1 image files updated
#     1 image files updated
#     1 image files updated
#     1 image files updated
#     1 image files updated
#     1 image files updated
#     1 image files updated
#     1 image files updated
#     1 image files updated
#     1 image files updated
#     1 image files updated
#     1 image files updated
#     1 image files updated
#     1 image files updated
#     1 image files updated
# Potholes ID:  [32, 1, 96, 35, 100, 8, 74, 11, 12, 75, 82, 19, 84, 87, 56, 28]
# Number of potholes detected:  16
# Tracking results saved to: data/road-pothole-1_pothole_tracking_results.csv
# Saved 16 full-frame images and label files to: data/road-pothole-1_pothole_frames

# %% [markdown]
# # END
